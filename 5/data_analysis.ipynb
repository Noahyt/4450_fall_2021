# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = [[1 , 2,  66.93], [1,3, 86.41], [1,4, 104.74], [1, 5, 122.23], [1, 6, 139.27], [.75 , 2,  56], [.75,3, 73.04], [.75,4, 89.53], [.75, 5, 105.22], [.75, 6, 120.63], [.5 , 2,  46.74], [.5,3, 61.14], [.5,4, 76.34], [.5, 5, 90.41], [.5, 6, 104.56]]

# %%
data = np.array(data)

# %%
df = pd.DataFrame(data, columns=['q', 'grid divisions', 'metric'])

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# {} &     q &  grid divisions &  metric \\
# \midrule
# 0  &  1.00 &             2.0 &   66.93 \\
# 1  &  1.00 &             3.0 &   86.41 \\
# 2  &  1.00 &             4.0 &  104.74 \\
# 3  &  1.00 &             5.0 &  122.23 \\
# 4  &  1.00 &             6.0 &  139.27 \\
# 5  &  0.75 &             2.0 &   56.00 \\
# 6  &  0.75 &             3.0 &   73.04 \\
# 7  &  0.75 &             4.0 &   89.53 \\
# 8  &  0.75 &             5.0 &  105.22 \\
# 9  &  0.75 &             6.0 &  120.63 \\
# 10 &  0.50 &             2.0 &   46.74 \\
# 11 &  0.50 &             3.0 &   61.14 \\
# 12 &  0.50 &             4.0 &   76.34 \\
# 13 &  0.50 &             5.0 &   90.41 \\
# 14 &  0.50 &             6.0 &  104.56 \\
# \bottomrule
# \end{tabular}

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')
ax.scatter(df['q'], df['grid divisions'])
ax.set_xlabel('q')
ax.set_ylabel('grid divisions')
ax.set_zlabel('metric')
# Out:
# Text(0.5, 0, 'metric')
